# %% [markdown]
# # Seasonal Decomposing
#
# * The analysis here is to compare residuals after removing the Season and the Trend with Additive or Multiplicative methods.
#   * Additive Method: `Y[t] = T[t] + S[t] + e[t]`
#   * Miltiplicative Method: `Y[t] = T[t] * S[t] * e[t]`
# * The purpose is to observe
#   * Which decomposing method could generate more random residuals?

# %%
import pandas as pd
import matplotlib.pyplot as plt
from statsmodels.tsa.seasonal import seasonal_decompose

# %%
sample_train_df1 = pd.read_pickle('sample_train_df1.pkl')
sample_test_df1 = pd.read_pickle('sample_test_df1.pkl')
print(sample_train_df1.shape, sample_test_df1.shape)

sample_train_df2 = pd.read_pickle('sample_train_df2.pkl')
sample_test_df2 = pd.read_pickle('sample_test_df2.pkl')
print(sample_train_df2.shape, sample_test_df2.shape)

sample_train_df1.head()
# Out:
# (100, 2) (14, 2)
# (100, 2) (10, 2)
#                purchase_amount  client_count
# purchase_date
# 2019-02-11            58743.49           470
# 2019-02-12            73984.82           686
# 2019-02-13            95749.55           876
# 2019-02-14           118723.62          1095
# 2019-02-15           152350.76          1379

# %% [markdown]
# ## Decomposing Plot
# Decompose trend, seasonality are separated out from data.
#
# ### Sample 1
# #### Additive Decomposing

# %%
col = sample_train_df1['client_count']

decomposition = seasonal_decompose(col, model='additive')
trend = decomposition.trend
seasonal = decomposition.seasonal
residual = decomposition.resid

plt.figure(figsize=(10,10))
plt.subplot(411)
plt.plot(col, label='Original')
plt.title('Additive Decomposing - Training Sample 1')
plt.legend(loc='best')
plt.subplot(412)
plt.plot(trend, label='Trend')
plt.legend(loc='best')
plt.subplot(413)
plt.plot(seasonal,label='Seasonality')
plt.legend(loc='best')
plt.subplot(414)
plt.plot(residual, label='Residuals')
plt.legend(loc='best')
plt.tight_layout()
plt.show()

# %%
col = sample_test_df1['client_count']

decomposition = seasonal_decompose(col, model='additive')
trend = decomposition.trend
seasonal = decomposition.seasonal
residual = decomposition.resid

plt.figure(figsize=(10,10))
plt.subplot(411)
plt.plot(col, label='Original')
plt.title('Additive Decomposing - Testing Sample 1')
plt.legend(loc='best')
plt.subplot(412)
plt.plot(trend, label='Trend')
plt.legend(loc='best')
plt.subplot(413)
plt.plot(seasonal,label='Seasonality')
plt.legend(loc='best')
plt.subplot(414)
plt.plot(residual, label='Residuals')
plt.legend(loc='best')
plt.tight_layout()
plt.show()

# %% [markdown]
# #### Multiplicative Decomposing

# %%
col = sample_train_df1['client_count']

decomposition = seasonal_decompose(col, model='multiplicative')
trend = decomposition.trend
seasonal = decomposition.seasonal
residual = decomposition.resid

plt.figure(figsize=(10,10))
plt.subplot(411)
plt.plot(col, label='Original')
plt.title('Multiplicative Decomposing - Training Sample 1')
plt.legend(loc='best')
plt.subplot(412)
plt.plot(trend, label='Trend')
plt.legend(loc='best')
plt.subplot(413)
plt.plot(seasonal,label='Seasonality')
plt.legend(loc='best')
plt.subplot(414)
plt.plot(residual, label='Residuals')
plt.legend(loc='best')
plt.tight_layout()
plt.show()

# %%
col = sample_test_df1['client_count']

decomposition = seasonal_decompose(col, model='multiplicative')
trend = decomposition.trend
seasonal = decomposition.seasonal
residual = decomposition.resid

plt.figure(figsize=(10,10))
plt.subplot(411)
plt.plot(col, label='Original')
plt.title('Multiplicative Decomposing - Testing Sample 1')
plt.legend(loc='best')
plt.subplot(412)
plt.plot(trend, label='Trend')
plt.legend(loc='best')
plt.subplot(413)
plt.plot(seasonal,label='Seasonality')
plt.legend(loc='best')
plt.subplot(414)
plt.plot(residual, label='Residuals')
plt.legend(loc='best')
plt.tight_layout()
plt.show()

# %% [markdown]
# #### Note
#
# * It seems that, for Sample 1, multiplicative method is better since its residuasl look more random, the residuals from the additive method has a bit trend left.

# %% [markdown]
# ### Sample 2
#
# #### Additive Decomposing

# %%
col = sample_train_df2['client_count']

decomposition = seasonal_decompose(col, model='additive')
trend = decomposition.trend
seasonal = decomposition.seasonal
residual = decomposition.resid

plt.figure(figsize=(10,10))
plt.subplot(411)
plt.plot(col, label='Original')
plt.title('Additive Decomposing - Training Sample 2')
plt.legend(loc='best')
plt.subplot(412)
plt.plot(trend, label='Trend')
plt.legend(loc='best')
plt.subplot(413)
plt.plot(seasonal,label='Seasonality')
plt.legend(loc='best')
plt.subplot(414)
plt.plot(residual, label='Residuals')
plt.legend(loc='best')
plt.tight_layout()
plt.show()

# %%
col = sample_test_df2['client_count']

decomposition = seasonal_decompose(col, model='additive', period=2)
trend = decomposition.trend
seasonal = decomposition.seasonal
residual = decomposition.resid

plt.figure(figsize=(10,10))
plt.subplot(411)
plt.plot(col, label='Original')
plt.title('Additive Decomposing - Testing Sample 2')
plt.legend(loc='best')
plt.subplot(412)
plt.plot(trend, label='Trend')
plt.legend(loc='best')
plt.subplot(413)
plt.plot(seasonal,label='Seasonality')
plt.legend(loc='best')
plt.subplot(414)
plt.plot(residual, label='Residuals')
plt.legend(loc='best')
plt.tight_layout()
plt.show()

# %% [markdown]
# #### Multiplicative Decomposing

# %%
col = sample_train_df2['client_count']

decomposition = seasonal_decompose(col, model='multiplicative')
trend = decomposition.trend
seasonal = decomposition.seasonal
residual = decomposition.resid

plt.figure(figsize=(10,10))
plt.subplot(411)
plt.plot(col, label='Original')
plt.title('Multiplicative Decomposing - Training Sample 2')
plt.legend(loc='best')
plt.subplot(412)
plt.plot(trend, label='Trend')
plt.legend(loc='best')
plt.subplot(413)
plt.plot(seasonal,label='Seasonality')
plt.legend(loc='best')
plt.subplot(414)
plt.plot(residual, label='Residuals')
plt.legend(loc='best')
plt.tight_layout()
plt.show()

# %%
col = sample_test_df2['client_count']

decomposition = seasonal_decompose(col, model='multiplicative', period=2)
trend = decomposition.trend
seasonal = decomposition.seasonal
residual = decomposition.resid

plt.figure(figsize=(10,10))
plt.subplot(411)
plt.plot(col, label='Original')
plt.title('Multiplicative Decomposing - TestingSample 2')
plt.legend(loc='best')
plt.subplot(412)
plt.plot(trend, label='Trend')
plt.legend(loc='best')
plt.subplot(413)
plt.plot(seasonal,label='Seasonality')
plt.legend(loc='best')
plt.subplot(414)
plt.plot(residual, label='Residuals')
plt.legend(loc='best')
plt.tight_layout()
plt.show()

# %% [markdown]
# #### Note
#
# * For Sample 2, both additive method and multiplicative method look good, residuals all look random. Better to check in the next forecasting section.

# %% [markdown]
# ## What Next
#
# * Next, I'm going to check the stationary of residuals, as well as for original time series, in order to get more insights which is a better choice for later forecasting experiments.
