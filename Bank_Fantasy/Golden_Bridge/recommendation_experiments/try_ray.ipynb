# %%
import pandas as pd
import numpy as np
import datetime

import warnings
warnings.filterwarnings("ignore")

# %%
import ray

ray.init()

# %%
target_merchant = '49th Parallel Grocery'

# %%
all_order_train = pd.read_pickle('../all_order_train.pkl')
all_order_test = pd.read_pickle('../all_order_test.pkl')
print(all_order_train.shape, all_order_test.shape)

all_order_train.head()
# Out:
# (33720820, 12) (98286, 12)
#    order_id  user_id  order_number  order_hour_of_day  product_id  \
# 0   2539329        1             1                  8         196
# 1   2231262       31            17                 11         196
# 2   3058369      195            34                 10         196
# 3   2257155      951             3                 20         196
# 4   1121647      992             7                 10         196
#
#   purchase_date                              merchant product_name  price  \
# 0    2019-02-13  L&M Markets (Hometown Grocers Co-op)         Soda   3.08
# 1    2019-03-10  L&M Markets (Hometown Grocers Co-op)         Soda   3.08
# 2    2019-02-25  L&M Markets (Hometown Grocers Co-op)         Soda   3.08
# 3    2019-03-09  L&M Markets (Hometown Grocers Co-op)         Soda   3.08
# 4    2019-03-08  L&M Markets (Hometown Grocers Co-op)         Soda   3.08
#
#          aisle department  week_number
# 0  soft drinks  beverages            7
# 1  soft drinks  beverages           10
# 2  soft drinks  beverages            9
# 3  soft drinks  beverages           10
# 4  soft drinks  beverages           10

# %%
target_train = all_order_train.loc[all_order_train['merchant'] == target_merchant]
target_test = all_order_test.loc[all_order_test['merchant'] == target_merchant]

print(target_train.shape, target_test.shape)
target_train.head()
# Out:
# (1365312, 12) (3850, 12)
#         order_id  user_id  order_number  order_hour_of_day  product_id  \
# 705698   2452257        7            20                  9       47272
# 705699   1867977     2850            19                 10       47272
# 705700   2879669    18719             1                 23       47272
# 705701    252427    38924             5                 13       47272
# 705702   1252985    55521             6                 16       47272
#
#        purchase_date               merchant  \
# 705698    2019-04-04  49th Parallel Grocery
# 705699    2019-03-14  49th Parallel Grocery
# 705700    2019-02-23  49th Parallel Grocery
# 705701    2019-03-31  49th Parallel Grocery
# 705702    2019-02-23  49th Parallel Grocery
#
#                                        product_name  price         aisle  \
# 705698  Antioxidant Infusions Beverage Malawi Mango   2.03  refrigerated
# 705699  Antioxidant Infusions Beverage Malawi Mango   2.03  refrigerated
# 705700  Antioxidant Infusions Beverage Malawi Mango   2.03  refrigerated
# 705701  Antioxidant Infusions Beverage Malawi Mango   2.03  refrigerated
# 705702  Antioxidant Infusions Beverage Malawi Mango   2.03  refrigerated
#
#        department  week_number
# 705698  beverages           14
# 705699  beverages           11
# 705700  beverages            8
# 705701  beverages           13
# 705702  beverages            8

# %%
all_order_train = all_order_train.loc[all_order_train['merchant'] != target_merchant]
all_order_test = all_order_test.loc[all_order_test['merchant'] != target_merchant]

print(all_order_train.shape, all_order_train.shape)
all_order_train.head()
# Out:
# (32355508, 12) (32355508, 12)
#    order_id  user_id  order_number  order_hour_of_day  product_id  \
# 0   2539329        1             1                  8         196
# 1   2231262       31            17                 11         196
# 2   3058369      195            34                 10         196
# 3   2257155      951             3                 20         196
# 4   1121647      992             7                 10         196
#
#   purchase_date                              merchant product_name  price  \
# 0    2019-02-13  L&M Markets (Hometown Grocers Co-op)         Soda   3.08
# 1    2019-03-10  L&M Markets (Hometown Grocers Co-op)         Soda   3.08
# 2    2019-02-25  L&M Markets (Hometown Grocers Co-op)         Soda   3.08
# 3    2019-03-09  L&M Markets (Hometown Grocers Co-op)         Soda   3.08
# 4    2019-03-08  L&M Markets (Hometown Grocers Co-op)         Soda   3.08
#
#          aisle department  week_number
# 0  soft drinks  beverages            7
# 1  soft drinks  beverages           10
# 2  soft drinks  beverages            9
# 3  soft drinks  beverages           10
# 4  soft drinks  beverages           10

# %%
@ray.remote
def get_merchant_data(merchant_df):
    merchant_size = merchant_df[['merchant', 'product_id']].astype('str').drop_duplicates()\
                                                  .groupby(['merchant'], as_index=False)['product_id']\
                                                  .agg('count').reset_index(drop=True).T.to_dict()
    return merchant_size[0]

# %%
merchant_lst = all_order_train['merchant'].unique()

test_lst = merchant_lst[0:2]
results = [get_merchant_data.remote(all_order_train.loc[all_order_train['merchant']==merchant][['merchant', 'product_id', 'order_id']]) for merchant in test_lst]
print(ray.get(results))
# Out:
# [{'merchant': 'L&M Markets (Hometown Grocers Co-op)', 'product_id': 30446}, {'merchant': 'Fairway Markets', 'product_id': 36478}]
